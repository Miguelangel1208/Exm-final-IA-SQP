# %% [markdown]
# #SCOPUS para una búsqueda bibliográfica

# %% [markdown]
# ##Búsqueda bibliográfica

# %% [markdown]
# Palabras clave: cascarilla de arroz, carbon activado, remoción de colorantes, Azul de metileno, rios contaminados
#
# Keywords: rice husk, activated carbon, dye removal, methylene blue, polluted rivers

# %% [markdown]
# ##PySCOPUS

# %%
# !pip install pyscopus==1.0.3a2
# Out:
# Collecting pyscopus==1.0.3a2
#   Downloading pyscopus-1.0.3a2-py3-none-any.whl.metadata (2.5 kB)
# Downloading pyscopus-1.0.3a2-py3-none-any.whl (11 kB)
# Installing collected packages: pyscopus
# Successfully installed pyscopus-1.0.3a2

# %% [markdown]
# Importar librerías

# %%
from pyscopus import Scopus
import numpy
import pandas as pd
import requests

# %%
key = "070d2de018ba61233277e64da31b55bb"
scopus = Scopus(key)

# %% [markdown]
# Keywords: rice husk, activated carbon, dye removal, methylene blue, polluted rivers
#
# Búsqueda #1:**Arrojó 0 resultados**
#
# TITLE-ABS-KEY((("rice husk") AND ("activated carbon") AND ("dye removal") AND ("methylene blue") AND ("polluted rivers")))
#
# Búsqueda #2:**Arrojó 8 resultados**
#
# TITLE-ABS-KEY((("rice husk") AND ("activated carbon") AND ("dye removal") AND ("methylene blue")))
#
# Búsqueda #3:**Arrojó 14 resultados**
#
# TITLE-ABS-KEY((("husk") AND ("activated carbon") AND ("dye removal") AND ("methylene blue")))

# %%
s = input("Ingresa tus palabras de búsqueda: ")
search_df = scopus.search(s, count=200,view='STANDARD')
# Out:
# Ingresa tus palabras de búsqueda: TITLE-ABS-KEY((("husk") AND ("activated carbon") AND ("dye removal") AND ("methylene blue")))

# %%
from IPython.display import display
display(search_df)
# Out:
#       scopus_id                                              title  \
# 0   85146329001  Understanding association between methylene bl...
# 1   85180538610  A comprehensive review on the sequestration of...
# 2   85096348692  Adsorption of methylene blue onto betel nut hu...
# 3   85083336784  Adsorption isotherms and kinetic modeling of m...
# 4   85081674516  Methylene blue adsorption on magnetic alginate...
# 5   84959934844  Removal of dyes from aqueous solutions using a...
# 6   84880933946  Dye removal of activated carbons prepared from...
# 7   84879343472  A friendly environmental material: Iron oxide ...
# 8   37549010986  Production of low-cost carbon adsorbents from ...
# 9   37249027160  Synthesis and properties of magnetic Fe<inf>3<...
# 10   0038613802  Physico-chemical characteristics of commercial...
# 11   0035472703  Kinetics and mechanism of removal of methylene...
# 12   0035108482  The potential application of activated carbon ...
# 13   0030406307  Adsorption characteristics of activated carbon...
#
#                                      publication_name      issn  isbn  \
# 0                       Water Science and Engineering  16742370  None
# 1                       Water Practice and Technology  1751231X  None
# 2                        Water Science and Technology  02731223  None
# 3                    Science of the Total Environment  00489697  None
# 4   International Journal of Biological Macromolec...  01418130  None
# 5                        Water Science and Technology  02731223  None
# 6                              Bioresource Technology  09608524  None
# 7                 Journal of Environmental Management  03014797  None
# 8                 Chemical Engineering Communications  00986445  None
# 9                                   Materials Letters  0167577X  None
# 10         Indian Journal of Environmental Protection  02537141  None
# 11                                  Dyes and Pigments  01437208  None
# 12                       Water Science and Technology  02731223  None
# 13                  Adsorption Science and Technology  02636174  None
#
#        eissn volume page_range  cover_date                              doi  \
# 0   24058106     16    154-164  2023-06-01        10.1016/j.wse.2022.12.006
# 1       None     18  3065-3108  2023-01-01             10.2166/wpt.2023.214
# 2   19969732     82  1932-1949  2020-11-01             10.2166/wst.2020.451
# 3   18791026    725       None  2020-07-10  10.1016/j.scitotenv.2020.138325
# 4   18790003    154    104-113  2020-07-01   10.1016/j.ijbiomac.2020.02.330
# 5       None     73  1122-1128  2016-03-01             10.2166/wst.2015.450
# 6   18732976    144    401-409  2013-01-01   10.1016/j.biortech.2013.07.002
# 7   10958630    127    206-211  2013-01-01    10.1016/j.jenvman.2013.05.017
# 8   15635201    195    386-403  2008-04-01        10.1080/00986440701707917
# 9       None     62    645-647  2008-02-29     10.1016/j.matlet.2007.06.049
# 10      None     22    495-499  2002-05-01                             None
# 11      None     51      25-40  2001-10-01    10.1016/S0143-7208(01)00056-0
# 12      None     43    245-252  2001-01-01            10.2166/wst.2001.0096
# 13      None     13    317-325  1996-01-01       10.1177/026361749601300502
#
#     citation_count                                        affiliation  \
# 0                9  [{'name': 'University of Jaffna', 'city': 'Jaf...
# 1               13  [{'name': 'Nnamdi Azikiwe University', 'city':...
# 2               33  [{'name': 'Khulna University Environmental Sci...
# 3              221  [{'name': 'Trường Đại học Công nghiệp thành ph...
# 4              235  [{'name': 'Hitit University', 'city': 'Corum',...
# 5               30  [{'name': 'Key Laboratory of Green Chemistry a...
# 6              166  [{'name': 'Dalian Polytechnic University', 'ci...
# 7               55  [{'name': 'Universidade Federal de Lavras', 'c...
# 8               45  [{'name': 'Jadavpur University', 'city': 'Kolk...
# 9              310  [{'name': 'Shanghai Jiao Tong University', 'ci...
# 10               5  [{'name': 'Ayya Nadar Janaki Ammal College', '...
# 11            1851  [{'name': 'Ayya Nadar Janaki Ammal College', '...
# 12              61  [{'name': 'Imperial College London', 'city': '...
# 13              37  [{'name': 'National Research Centre', 'city': ...
#
#    aggregation_type subtype_description authors  \
# 0           Journal             Article      []
# 1           Journal             Article      []
# 2           Journal             Article      []
# 3           Journal             Article      []
# 4           Journal             Article      []
# 5           Journal             Article      []
# 6           Journal             Article      []
# 7           Journal             Article      []
# 8           Journal             Article      []
# 9           Journal             Article      []
# 10          Journal             Article      []
# 11          Journal             Article      []
# 12          Journal    Conference Paper      []
# 13          Journal             Article      []
#
#                                             full_text
# 0   https://api.elsevier.com/content/article/eid/1...
# 1                                                None
# 2                                                None
# 3   https://api.elsevier.com/content/article/eid/1...
# 4   https://api.elsevier.com/content/article/eid/1...
# 5                                                None
# 6   https://api.elsevier.com/content/article/eid/1...
# 7   https://api.elsevier.com/content/article/eid/1...
# 8                                                None
# 9   https://api.elsevier.com/content/article/eid/1...
# 10                                               None
# 11  https://api.elsevier.com/content/article/eid/1...
# 12                                               None
# 13                                               None

# %%
search_df.shape
# Out:
# (14, 18)

# %% [markdown]
# Añadimos una columna "Abstract" al dataframe generado

# %%
def get_abstract(doi):
  try:
    abstract = scopus.abstract(doi)
    return abstract['abstract']
  except:
    return None

# %%
search_df['abstract'] = search_df['doi'].apply(get_abstract)

# %%
display(search_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2160d3b520c2> in <cell line: 1>()
# ----> 1 display(search_df)
#
# NameError: name 'search_df' is not defined

# %%
search_df.to_csv('pregunta_2a.csv', index=False)

# %% [markdown]
# #Diagrama de barras con los tipos de publicación versus la cantidad.

# %%
search_df.subtype_description.unique()
# Out:
# array(['Article', 'Conference Paper'], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Contar las ocurrencias de cada tipo de publicación y ordenar los datos por el índice
subtype_description = search_df['subtype_description'].value_counts()

# Crear el gráfico de barras con coloración por tipo de publicación
ax = sns.barplot(x=subtype_description.index, y=subtype_description.values, palette='viridis')

plt.ylabel('Cantidad')
plt.title('Tipo de publicación')

ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%.0f'))

plt.show()
# Out:
# <ipython-input-61-10f1324a61c7>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=subtype_description.index, y=subtype_description.values, palette='viridis')

# %% [markdown]
# #USANDO MISSINGNO

# %%
pip install missingno
# Out:
# Requirement already satisfied: missingno in /usr/local/lib/python3.10/dist-packages (0.5.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from missingno) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from missingno) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from missingno) (1.13.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from missingno) (0.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn->missingno) (2.1.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn->missingno) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn->missingno) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)

# %%
import pandas as pd
collisions = pd.read_csv("pregunta_2a.csv")

# %%
import missingno as msno
# %matplotlib inline
msno.matrix(collisions.sample(14))
# Out:
# <Axes: >

# %%
msno.bar(collisions.sample(14))
# Out:
# <Axes: >

# %% [markdown]
# Se encontró que sí existen datos faltantes especialmente para las columnas "isbn(14)" "eissn(7)", "Page_range(1)" "doi(1)" " full_text(7)"  "abstract (14)"

# %%
df.loc[0, 'abstract'] = 'Water pollution caused by industrial dyes has become a severe problem in the modern world. Biosorbents can be used in an eco-friendly manner to remove industrial dyes. In this study, five biosorbents were selected: palmyrah sprout casing (PSC), manioc peel, lime peel, king coconut husk, and coconut kernel. Batch adsorption experiments were conducted to identify the best biosorbent with the highest ability to adsorb methylene blue (MB) from wastewater. The detailed mechanisms of PSC used in the adsorptive removal of MB in aqueous phase were investigated. Of the five biosorbents, PSC exhibited the best removal performance with an adsorption capacity at equilibrium (qe) of 27.67 mg/g. The qe values of lime peel, king coconut husk, manioc peel, and coconut kernel were 24.25 mg/g, 15.29 mg/g, 10.84 mg/g, and 7.06 mg/g, respectively. To explain the mechanisms of MB adsorption with the selected biosorbents, the Fourier transform infrared (FTIR) spectrometry and X-ray diffraction (XRD) analyses were performed to characterize functional properties, and isotherm, kinetic, rate-limiting, and thermodynamic analyses were conducted. The FTIR analysis revealed that different biosorbents had different functional properties on their adsorptive surfaces. The FTIR and XRD results obtained before and after MB adsorption with PSC indicated that the surface functional groups of carbonyl and hydroxyl actively participated in the removal process. According to the isotherm analysis, monolayer adsorption was observed with the Langmuir model with a determination coefficient of 0.998. The duration to reach the maximum adsorption capacity for MB adsorption with PSC was 120 min, and the adsorption process was exothermic due to the negative enthalpy change (−9.950 kJ/mol). Moreover, the boundary layer thickness and intraparticle diffusion were the rate-limiting factors in the adsorption process. As a new biosorbent for MB adsorption, PSC could be used in activated carbon production to enhance the performance of dye removal.'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-28f7dfae1060> in <cell line: 1>()
# ----> 1 df.loc[0, 'abstract'] = 'Water pollution caused by industrial dyes has become a severe problem in the modern world. Biosorbents can be used in an eco-friendly manner to remove industrial dyes. In this study, five biosorbents were selected: palmyrah sprout casing (PSC), manioc peel, lime peel, king coconut husk, and coconut kernel. Batch adsorption experiments were conducted to identify the best biosorbent with the highest ability to adsorb methylene blue (MB) from wastewater. The detailed mechanisms of PSC used in the adsorptive removal of MB in aqueous phase were investigated. Of the five biosorbents, PSC exhibited the best removal performance with an adsorption capacity at equilibrium (qe) of 27.67 mg/g. The qe values of lime peel, king coconut husk, manioc peel, and coconut kernel were 24.25 mg/g, 15.29 mg/g, 10.84 mg/g, and 7.06 mg/g, respectively. To explain the mechanisms of MB adsorption with the selected biosorbents, the Fourier transform infrared (FTIR) spectrometry and X-ray diffraction (XRD) analyses were performed to characterize functional properties, and isotherm, kinetic, rate-limiting, and thermodynamic analyses were conducted. The FTIR analysis revealed that different biosorbents had different functional properties on their adsorptive surfaces. The FTIR and XRD results obtained before and after MB adsorption with PSC indicated that the ...
#
# NameError: name 'df' is not defined

# %%
df.at[1, 'abstract'] = 'Water pollution caused by industrial dyes has become a severe problem in the modern world. Biosorbents can be used in an eco-friendly manner to remove industrial dyes. In this study, five biosorbents were selected: palmyrah sprout casing (PSC), manioc peel, lime peel, king coconut husk, and coconut kernel. Batch adsorption experiments were conducted to identify the best biosorbent with the highest ability to adsorb methylene blue (MB) from wastewater. The detailed mechanisms of PSC used in the adsorptive removal of MB in aqueous phase were investigated. Of the five biosorbents, PSC exhibited the best removal performance with an adsorption capacity at equilibrium (qe) of 27.67 mg/g. The qe values of lime peel, king coconut husk, manioc peel, and coconut kernel were 24.25 mg/g, 15.29 mg/g, 10.84 mg/g, and 7.06 mg/g, respectively. To explain the mechanisms of MB adsorption with the selected biosorbents, the Fourier transform infrared (FTIR) spectrometry and X-ray diffraction (XRD) analyses were performed to characterize functional properties, and isotherm, kinetic, rate-limiting, and thermodynamic analyses were conducted. The FTIR analysis revealed that different biosorbents had different functional properties on their adsorptive surfaces. The FTIR and XRD results obtained before and after MB adsorption with PSC indicated that the surface functional groups of carbonyl and hydroxyl actively participated in the removal process. According to the isotherm analysis, monolayer adsorption was observed with the Langmuir model with a determination coefficient of 0.998. The duration to reach the maximum adsorption capacity for MB adsorption with PSC was 120 min, and the adsorption process was exothermic due to the negative enthalpy change (−9.950 kJ/mol). Moreover, the boundary layer thickness and intraparticle diffusion were the rate-limiting factors in the adsorption process. As a new biosorbent for MB adsorption, PSC could be used in activated carbon production to enhance the performance of dye removal.'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0db1b971b6f3> in <cell line: 1>()
# ----> 1 df.at[1, 'abstract'] = 'Water pollution caused by industrial dyes has become a severe problem in the modern world. Biosorbents can be used in an eco-friendly manner to remove industrial dyes. In this study, five biosorbents were selected: palmyrah sprout casing (PSC), manioc peel, lime peel, king coconut husk, and coconut kernel. Batch adsorption experiments were conducted to identify the best biosorbent with the highest ability to adsorb methylene blue (MB) from wastewater. The detailed mechanisms of PSC used in the adsorptive removal of MB in aqueous phase were investigated. Of the five biosorbents, PSC exhibited the best removal performance with an adsorption capacity at equilibrium (qe) of 27.67 mg/g. The qe values of lime peel, king coconut husk, manioc peel, and coconut kernel were 24.25 mg/g, 15.29 mg/g, 10.84 mg/g, and 7.06 mg/g, respectively. To explain the mechanisms of MB adsorption with the selected biosorbents, the Fourier transform infrared (FTIR) spectrometry and X-ray diffraction (XRD) analyses were performed to characterize functional properties, and isotherm, kinetic, rate-limiting, and thermodynamic analyses were conducted. The FTIR analysis revealed that different biosorbents had different functional properties on their adsorptive surfaces. The FTIR and XRD results obtained before and after MB adsorption with PSC indicated that the s...
#
# NameError: name 'df' is not defined
